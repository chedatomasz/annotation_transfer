# %%
from Bio import SeqIO
def records(path):
    records = list(SeqIO.parse(path, "fasta"))
    return records

# %%
def ids_from_gopredsim_annotation(pth):
    with open(pth, 'r') as opened:
        ids = set(x.split()[0] for x in opened.readlines())
        print(len(ids))
    return ids

# %% [markdown]
# # Determine the sets of train and test ids

# %% [markdown]
# This is the training set originally provided in the CAFA3 challenge, although use could also use other information

# %%
orig_cafa3_file = "uniprot_sprot_exp.fasta"
orig_cafa3_ids_set = set(str(x.id) for x in records(orig_cafa3_file))
len(orig_cafa3_ids_set)
# Out:
# 66841

# %% [markdown]
# This is the training set prepared by goPredSim developers,
# closely matching the CAFA3 set, with a corresponding temporal cutoff

# %%
gopredsim_file = "goa_annotations_exp_2017.txt"
gopredsim_ids_set = ids_from_gopredsim_annotation(gopredsim_file)
# Out:
# 68038

# %% [markdown]
# We take their intersection

# %%
train_ids = orig_cafa3_ids_set.intersection(gopredsim_ids_set)

# %%
len(train_ids)
# Out:
# 62626

# %% [markdown]
# For the test set, we take the set of proteins which got new annotations in the CAFA3 review period

# %%
test_ids = set(str(x.id) for x in records("cafa3_targets.fasta"))

# %%
len(test_ids)
# Out:
# 3328

# %% [markdown]
# # Prepare the sets of embeddings in format required by goPredSim

# %%
embeddings_folder = "prepared_embeddings"

# %%
import numpy as np
import os
def get_dict_from_separate_files(embeddings_file, ids_file):
    embeddings = np.load(embeddings_file, allow_pickle=True)
    ids = np.load(ids_file, allow_pickle=True)
    embed_dict = {id_: em for id_, em in zip(ids, embeddings)}
    return embed_dict

# %%
def get_subset(source, ids, allow_missing=False):
    res = dict()
    for i in ids:
        try:
            res[i]=source[i]
        except KeyError as e:
            print(f"missing embedding for {i}")
            if not allow_missing:
                raise e
    return res

# %%
import pickle
def save_dict(di, name):
    with open(f"{name}.pkl", 'wb') as fp:
        pickle.dump(di, fp)

# %%
def prepare_separate(model, split):
    assert split in ("train", "test")
    model_data_ids = os.path.join(embeddings_folder, f"{model}_{split}_ids.npy")
    model_data_ems = os.path.join(embeddings_folder, f"{model}_{split}_embeddings.npy")
    model_data_full = get_dict_from_separate_files(model_data_ems, model_data_ids)
    ids = train_ids if split == "train" else test_ids
    model_data = get_subset(model_data_full, ids)
    save_dict(model_data, f"{model}.{split}")

# %%
import h5py
import numpy as np
import tqdm

# Code based on that of goPredSim
def read_h5_embeddings(embeddings_in):
    """A2ASS6
    Read embeddings from h5 file generated by bio_embeddings pipeline
    :param embeddings_in: 
    :return: 
    """
    embeddings = dict()
    with h5py.File(embeddings_in, 'r') as f:
        for key, embedding in tqdm.tqdm(f.items()):
            original_id = embedding.attrs['original_id']
            embeddings[original_id] = np.array(embedding)
            
    return embeddings

# %%
def prepare_from_h5(model, split, allow_missing=False):
    assert split in ("train", "test")
    if split=="train":
        data_path = os.path.join(embeddings_folder, f"{model}_goa_2017.h5")
    else:
        data_path = os.path.join(embeddings_folder, f"{model}_cafa3_targets.h5")
        
    model_data_full = read_h5_embeddings(data_path)
    ids = train_ids if split == "train" else test_ids
    model_data = get_subset(model_data_full, ids, allow_missing=allow_missing)
    save_dict(model_data, f"{model}.{split}")

# %% [markdown]
# proteinbert

# %%
prepare_separate("proteinbert", "train")
prepare_separate("proteinbert", "test")

# %% [markdown]
# protbert

# %%
prepare_separate("protbert", "train")
prepare_separate("protbert", "test")

# %% [markdown]
# esm2

# %%
import pickle
def esm2_filter(file):
    with open(file, 'rb') as opened:
        di = pickle.load(opened)
    out = {i: o[33] for i, o in di.items()}
    with open(file, 'wb') as fp:
        pickle.dump(out, fp)

# %%
prepare_separate("esm2", "train")
prepare_separate("esm2", "test")

# %%
import pickle
def esm2_filter2(file):
    with open(file, 'rb') as opened:
        di = pickle.load(opened)
    out = {i: o.numpy() for i, o in di.items()}
    with open(file, 'wb') as fp:
        pickle.dump(out, fp)

# %%
esm2_filter("esm2.train.pkl")
esm2_filter("esm2.test.pkl")

# %%
esm2_filter2("esm2.train.pkl")
esm2_filter2("esm2.test.pkl")

# %% [markdown]
# prott5

# %%
prepare_from_h5("prott5", "train", allow_missing=True)
# Out:
# 100%|██████████| 307278/307278 [01:27<00:00, 3501.78it/s]
# missing embedding for A2ASS6
# missing embedding for G4SLH0
# missing embedding for Q9I7U4
# missing embedding for Q8WZ42
# missing embedding for Q8WXI7
# missing embedding for Q09165

# %%
prepare_from_h5("prott5", "test")
# Out:
# 100%|██████████| 3328/3328 [00:00<00:00, 3546.41it/s]

# %% [markdown]
# seqvec

# %%
prepare_from_h5("seqvec", "train", allow_missing=True)
prepare_from_h5("seqvec", "test")
# Out:
# 100%|██████████| 307278/307278 [01:32<00:00, 3330.10it/s]
# missing embedding for A2ASS6
# missing embedding for G4SLH0
# missing embedding for Q9I7U4
# missing embedding for Q8WZ42
# missing embedding for Q8WXI7
# missing embedding for Q09165
# 100%|██████████| 3328/3328 [00:01<00:00, 2725.63it/s]

# %% [markdown]
# preexisting protbert

# %%
prepare_from_h5("theirprotbert", "train", allow_missing=True)
prepare_from_h5("theirprotbert", "test")
# Out:
# 100%|██████████| 307278/307278 [01:35<00:00, 3212.55it/s]
# missing embedding for Q09165
# missing embedding for Q9I7U4
# missing embedding for Q8WZ42
# missing embedding for G4SLH0
# missing embedding for A2ASS6
# missing embedding for Q8WXI7
# 100%|██████████| 3328/3328 [00:01<00:00, 3231.66it/s]

# %%
import pickle
def load(file):
    with open(file, 'rb') as opened:
        di = pickle.load(opened)
        return di

# %%
x = load("project/theirprotbert.test.pkl")

# %%
import numpy as np
lens = [np.linalg.norm(arr) for arr in x.values()]

# %%
lens
# Out:
# [1.9333407,
#  1.7303805,
#  1.4600827,
#  1.5873901,
#  1.3586987,
#  1.4717962,
#  1.6300994,
#  1.6050678,
#  1.7198772,
#  1.7099538,
#  1.551347,
#  1.7179743,
#  1.5142007,
#  2.2130406,
#  1.169941,
#  1.6037604,
#  1.7348386,
#  2.2893074,
#  1.6679951,
#  1.8446026,
#  1.8347366,
#  1.7651032,
#  1.6979343,
#  2.1512818,
#  1.8470639,
#  1.8877944,
#  1.9986861,
#  1.7125064,
#  1.4372009,
#  1.9364086,
#  1.998567,
#  1.5888938,
#  1.9102566,
#  1.7622368,
#  1.2822216,
#  1.6654811,
#  1.4809779,
#  3.051137,
#  1.3258262,
#  3.2046516,
#  1.4510617,
#  2.0072434,
#  2.419381,
#  1.4125732,
#  2.0263689,
#  1.7718647,
#  1.9581747,
#  1.3034966,
#  1.6556896,
#  2.0884104,
#  1.9208376,
#  1.6679215,
#  1.7957593,
#  1.5060405,
#  1.8769077,
#  2.1537368,
#  2.0325866,
#  2.0905266,
#  1.9344875,
#  1.5757715,
#  1.3635778,
#  1.7496706,
#  1.5321747,
#  1.8782963,
#  2.0566115,
#  1.6598191,
#  2.0862577,
#  1.7946155,
#  2.394747,
#  1.4561296,
#  1.2275468,
#  2.257842,
#  1.9462242,
#  2.1134107,
#  1.3143905,
#  1.2325059,
#  1.3569176,
#  1.6312116,
#  1.7050123,
#  1.5559263,
#  2.4675303,
#  1.7414445,
#  1.8890586,
#  1.4374515,
#  2.3147109,
#  2.1388936,
#  1.9681262,
#  1.6538032,
#  1.913046,
#  1.4016309,
#  1.5058628,
#  1.6800352,
#  1.6534545,
#  1.9245583,
#  1.7741898,
#  1.3648536,
#  1.9407386,
#  1.6349281,
#  2.2375395,
#  1.9498662,
#  1.7355317,
#  1.2950987,
#  1.7398709,
#  1.850874,
#  1.9336673,
#  1.8025401,
#  1.9809353,
#  2.7978323,
#  2.364899,
#  1.7928797,
#  2.12871,
#  1.448187,
#  1.3265203,
#  1.6537457,
#  1.7374535,
#  1.4317333,
#  1.629207,
#  1.5895487,
#  1.4491365,
#  1.6219014,
#  1.4332519,
#  1.4658539,
#  1.3496004,
#  1.3478827,
#  1.7117004,
#  1.7687538,
#  1.8605905,
#  1.4689784,
#  1.7241595,
#  1.8217087,
#  1.7622305,
#  1.4195268,
#  1.5767199,
#  1.7495296,
#  1.972669,
#  2.266933,
#  1.533618,
#  2.4237106,
#  1.5576942,
#  1.904523,
#  1.8131545,
#  1.5151415,
#  1.5115134,
#  1.9164428,
#  1.4081175,
#  2.1316996,
#  1.9556957,
#  1.9100211,
#  1.069407,
#  1.4608316,
#  1.4975412,
#  1.4710382,
#  1.2956064,
#  2.3092327,
#  1.939718,
#  1.8079432,
#  2.2359285,
#  1.8706453,
#  1.8452312,
#  1.600777,
#  1.6923332,
#  2.1207297,
#  1.571893,
#  2.7318237,
#  1.8079853,
#  2.0492384,
#  1.5575975,
#  1.4798417,
#  1.5450239,
#  1.4198883,
#  1.2666733,
#  1.6908356,
#  1.855976,
#  1.4828984,
#  1.3349179,
#  1.8740541,
#  2.1058326,
#  1.560847,
#  1.3902216,
#  1.369616,
#  1.6212754,
#  1.856348,
#  1.4569356,
#  1.5038447,
#  1.5841165,
#  1.9914336,
#  2.6798968,
#  1.9696219,
#  2.021894,
#  1.3146012,
#  2.6357439,
#  1.9198195,
#  2.0319543,
#  2.6457388,
#  1.5540249,
#  1.7071244,
#  1.7948974,
#  1.923308,
#  1.4636732,
#  1.8172135,
#  2.0685859,
#  2.3160908,
#  2.0475023,
#  1.6519777,
#  1.8036945,
#  2.015311,
#  1.8697534,
#  1.67042,
#  2.096205,
#  1.9379226,
#  1.3422326,
#  1.7049625,
#  2.2024233,
#  2.1179235,
#  1.7702141,
#  1.902269,
#  1.9629685,
#  1.9377048,
#  1.6619631,
#  1.8124411,
#  1.5760564,
#  1.6518517,
#  1.484098,
#  1.5532864,
#  1.8484302,
#  1.348578,
#  1.6315112,
#  1.920304,
#  2.1599736,
#  3.3498423,
#  1.8867885,
#  1.8284389,
#  2.71256,
#  1.22502,
#  1.5925962,
#  1.562318,
#  1.642821,
#  2.1627088,
#  1.5020803,
#  1.9723583,
#  1.6242212,
#  1.9994776,
#  1.0975227,
#  2.104633,
#  1.7646688,
#  1.4685929,
#  1.8900688,
#  2.4884603,
#  1.8609068,
#  1.7911671,
#  1.7910788,
#  1.8535868,
#  1.9326245,
#  1.8210137,
#  2.0501456,
#  1.4836389,
#  1.7947714,
#  1.4041038,
#  1.7809244,
#  1.3428771,
#  1.837288,
#  1.9323403,
#  1.4658911,
#  1.5316144,
#  1.9380016,
#  1.3711476,
#  1.5524049,
#  1.4857075,
#  2.2163498,
#  1.9872323,
#  2.7879653,
#  2.260871,
#  2.9389691,
#  1.7913271,
#  1.5353707,
#  1.7699742,
#  1.7378856,
#  1.92538,
#  2.0258913,
#  1.4813045,
#  1.5615866,
#  1.426633,
#  1.3504168,
#  1.6232406,
#  1.8990879,
#  1.3366799,
#  1.8584898,
#  1.4056402,
#  2.0223777,
#  2.2732332,
#  1.3001928,
#  1.465417,
#  2.006934,
#  1.744844,
#  1.9282624,
#  2.1091747,
#  1.6796081,
#  2.1120164,
#  1.4285058,
#  1.7969626,
#  1.7041402,
#  1.4834737,
#  1.6409397,
#  1.6176196,
#  2.935246,
#  1.8668618,
#  1.6857564,
#  1.8487852,
#  1.6849418,
#  1.5815192,
#  1.3582832,
#  1.8966297,
#  2.0415213,
#  1.9063599,
#  1.8034581,
#  1.5609827,
#  1.8437549,
#  2.224022,
#  2.1163406,
#  1.8253068,
#  1.8881193,
#  1.8705939,
#  1.39831,
#  1.6350001,
#  1.5634896,
#  1.608722,
#  2.508907,
#  2.4236634,
#  1.3276764,
#  1.7181143,
#  1.4446551,
#  1.7536368,
#  2.1967144,
#  1.3277155,
#  2.167589,
#  1.673937,
#  1.1950939,
#  1.7871712,
#  1.8617375,
#  2.6281183,
#  1.7054137,
#  1.692265,
#  1.5806434,
#  2.0180469,
#  1.7078942,
#  2.9086008,
#  1.732296,
#  1.8928225,
#  1.5950654,
#  1.6224337,
#  1.1922208,
#  1.5489318,
#  1.519391,
#  1.3813658,
#  1.4036082,
#  1.1773103,
#  1.726114,
#  1.4705187,
#  2.4965818,
#  1.76093,
#  1.6937065,
#  2.5619166,
#  2.178043,
#  2.0320613,
#  1.6601137,
#  1.4070421,
#  1.9274468,
#  1.5892836,
#  1.4685552,
#  1.6297094,
#  2.044891,
#  1.49499,
#  1.8232911,
#  1.4564981,
#  1.7237722,
#  2.6012084,
#  1.8952254,
#  1.8251821,
#  1.5391499,
#  1.8270276,
#  1.9386889,
#  1.4664115,
#  3.4366996,
#  2.0480206,
#  1.7449424,
#  1.4855995,
#  1.8466676,
#  1.5994898,
#  1.7019683,
#  1.3814206,
#  1.8003011,
#  2.1335278,
#  1.7001388,
#  1.3724025,
#  1.8231668,
#  1.4923944,
#  2.0635824,
#  2.0537732,
#  1.9575667,
#  1.7679126,
#  2.253232,
#  2.0259187,
#  1.6084201,
#  1.7068616,
#  1.8475993,
#  1.6881279,
#  1.5617374,
#  1.3360239,
#  1.6188052,
#  1.9455338,
#  1.2237831,
#  1.5386953,
#  1.417844,
#  2.3645058,
#  1.6829911,
#  1.4480737,
#  1.9348923,
#  1.3173473,
#  1.5789193,
#  2.13249,
#  2.0754528,
#  2.1854706,
#  1.9409491,
#  1.7467848,
#  1.2367753,
#  1.9968175,
#  1.4458627,
#  1.4351423,
#  1.770983,
#  1.8482708,
#  3.1451368,
#  1.4715056,
#  1.3761207,
#  1.3173492,
#  1.7562928,
#  2.8171742,
#  1.4060485,
#  1.5494214,
#  1.8934921,
#  1.709326,
#  1.5113173,
#  1.8278843,
#  1.7479107,
#  1.8463833,
#  1.5615652,
#  2.4671614,
#  1.7843266,
#  1.8001,
#  1.3259902,
#  1.5838604,
#  1.8931736,
#  1.3740392,
#  1.4257164,
#  2.012135,
#  1.4954132,
#  1.9764123,
#  1.5605096,
#  1.4608489,
#  1.3664557,
#  1.6048487,
#  1.7413785,
#  2.2262836,
#  1.7081997,
#  1.4164009,
#  1.899944,
#  1.9923811,
#  2.1494348,
#  1.6078819,
#  2.0779483,
#  2.0636559,
#  1.5557517,
#  1.7500851,
#  1.347552,
#  1.7052808,
#  1.5836731,
#  1.6003567,
#  1.9779409,
#  1.8232161,
#  2.1371317,
#  2.1880438,
#  1.5716592,
#  1.7218956,
#  1.5957605,
#  3.340649,
#  1.5744171,
#  1.3884801,
#  1.3739861,
#  1.7459898,
#  1.5702659,
#  1.9877596,
#  1.2742413,
#  1.3704103,
#  1.9199375,
#  1.327203,
#  1.6149088,
#  2.245022,
#  1.3103198,
#  1.5660642,
#  1.5860404,
#  1.8316252,
#  1.789408,
#  1.728535,
#  1.356721,
#  1.5497757,
#  1.9345069,
#  1.8637162,
#  1.989874,
#  2.498586,
#  2.1468165,
#  1.232685,
#  1.514113,
#  2.1043222,
#  2.3254075,
#  1.7350421,
#  1.3370819,
#  1.5078303,
#  1.5212666,
#  1.3583184,
#  1.747551,
#  1.5729765,
#  1.3289111,
#  1.5120792,
#  1.6788992,
#  1.4017475,
#  1.5828823,
#  1.4541414,
#  1.9572431,
#  1.8963104,
#  1.5621272,
#  1.9516187,
#  2.1355748,
#  1.4991957,
#  1.7701559,
#  1.6089581,
#  1.6510857,
#  1.8942262,
#  2.1503177,
#  1.5036919,
#  1.6914539,
#  1.5431132,
#  2.898429,
#  1.6110578,
#  2.2345629,
#  1.7165315,
#  1.4091765,
#  1.6029308,
#  1.7954099,
#  1.5235065,
#  1.997599,
#  1.663333,
#  1.464574,
#  1.8781122,
#  1.6641778,
#  1.9239987,
#  1.3791426,
#  1.3733202,
#  2.1825292,
#  1.5037403,
#  1.6222379,
#  1.9820542,
#  2.120778,
#  1.7553729,
#  1.675681,
#  1.5884029,
#  1.8241707,
#  1.838115,
#  1.612268,
#  1.8891661,
#  1.3009672,
#  1.5775056,
#  2.278271,
#  1.6496953,
#  2.0342593,
#  1.7634517,
#  1.7164332,
#  1.6427081,
#  1.4139451,
#  1.543202,
#  1.7454126,
#  1.9936546,
#  1.9278445,
#  1.4553187,
#  1.9063318,
#  1.6632596,
#  1.4501054,
#  1.7864782,
#  1.575142,
#  1.6982427,
#  2.1743722,
#  1.7454365,
#  2.8431656,
#  1.5699998,
#  1.4240057,
#  1.7167659,
#  1.9905227,
#  1.5056133,
#  1.7162371,
#  1.8608035,
#  1.4370794,
#  2.411535,
#  2.275644,
#  1.8413471,
#  2.2181127,
#  1.4043409,
#  1.3649279,
#  1.7890296,
#  1.8228202,
#  1.4693273,
#  1.5807513,
#  1.9867107,
#  1.4291456,
#  1.9454827,
#  2.1435542,
#  1.5734701,
#  2.0630088,
#  1.4022462,
#  1.3969587,
#  1.4535141,
#  1.5546254,
#  1.6526492,
#  2.0234838,
#  1.395878,
#  1.6002171,
#  1.4716516,
#  1.5513289,
#  1.2171288,
#  1.6439233,
#  1.9385318,
#  1.5477134,
#  1.6298387,
#  3.4892905,
#  1.9195868,
#  1.807521,
#  1.8118018,
#  1.3537364,
#  2.1443646,
#  2.0460496,
#  1.4248108,
#  1.7206774,
#  1.7307805,
#  1.7538359,
#  1.7394081,
#  2.7564898,
#  2.33936,
#  1.3024368,
#  1.3146058,
#  1.3617102,
#  1.9787403,
#  1.9186312,
#  1.5928664,
#  2.3043973,
#  1.7019829,
#  2.2541502,
#  1.2053399,
#  1.8318278,
#  1.6554997,
#  1.534152,
#  1.9791888,
#  1.3193877,
#  1.9750085,
#  1.5015975,
#  1.5180688,
#  1.3085248,
#  1.9050599,
#  1.7695013,
#  1.4786159,
#  1.6500726,
#  1.4296033,
#  1.3050368,
#  1.5610111,
#  2.098593,
#  1.8284358,
#  1.4163831,
#  2.4957519,
#  1.561296,
#  1.856036,
#  1.6271523,
#  1.7948979,
#  1.8488214,
#  1.8273301,
#  2.0584984,
#  1.8226086,
#  1.5100085,
#  3.0456767,
#  1.9475955,
#  2.0616753,
#  1.3942306,
#  1.563227,
#  1.6814767,
#  1.9121531,
#  2.0051093,
#  1.8841243,
#  1.8408507,
#  1.1587099,
#  1.7852131,
#  2.1212611,
#  1.7986258,
#  1.4452995,
#  1.6477727,
#  1.9556305,
#  1.8777243,
#  2.037664,
#  1.6958658,
#  2.023884,
#  1.6384035,
#  1.2809526,
#  1.9909798,
#  1.8577234,
#  1.7907025,
#  1.4222835,
#  2.063523,
#  1.4248273,
#  1.6520957,
#  1.7664026,
#  1.1622272,
#  1.336738,
#  1.5746961,
#  1.3302333,
#  2.5153441,
#  1.710532,
#  2.013923,
#  1.9531047,
#  1.3392348,
#  1.6859155,
#  1.9870348,
#  1.9604143,
#  1.4446307,
#  1.1248326,
#  1.6040598,
#  1.5049856,
#  2.2446704,
#  1.5080836,
#  1.5364692,
#  1.4800647,
#  2.027741,
#  1.7492772,
#  1.6836423,
#  1.4436435,
#  1.8611137,
#  1.6553923,
#  2.3815217,
#  2.0015683,
#  1.9962528,
#  1.9231333,
#  1.6156127,
#  1.8209617,
#  1.5689622,
#  1.3905067,
#  1.4791598,
#  1.6526397,
#  1.6232907,
#  1.7517784,
#  1.6884218,
#  2.7694225,
#  2.1891313,
#  1.8176576,
#  1.878189,
#  1.5158657,
#  1.9758217,
#  1.5654081,
#  1.4744637,
#  1.6720468,
#  1.6890317,
#  1.6606904,
#  1.3034374,
#  1.9058622,
#  1.7307684,
#  1.4166957,
#  1.8414637,
#  1.484643,
#  1.9727801,
#  1.4605052,
#  1.807129,
#  2.1417594,
#  1.9088638,
#  1.7097459,
#  1.4135321,
#  2.4267812,
#  1.4679168,
#  1.8133854,
#  1.5947108,
#  1.4262099,
#  1.8294537,
#  1.5782778,
#  1.9619285,
#  1.8731183,
#  1.4915888,
#  1.3743596,
#  1.9817814,
#  1.8817371,
#  1.6420387,
#  1.9186236,
#  1.2545625,
#  1.8769537,
#  1.9887104,
#  1.956185,
#  2.1693583,
#  1.6735306,
#  2.2921793,
#  1.7409645,
#  1.4630066,
#  1.9479191,
#  2.0372612,
#  1.849685,
#  2.2196531,
#  1.8674145,
#  1.9819695,
#  2.0638583,
#  2.0820408,
#  1.5847257,
#  1.1545285,
#  1.5742502,
#  1.7512006,
#  1.8758093,
#  2.1118984,
#  2.0230892,
#  2.1686964,
#  1.3450984,
#  1.6401565,
#  1.8919336,
#  1.422871,
#  1.8844748,
#  1.6156622,
#  2.4768336,
#  1.5782944,
#  1.5468817,
#  2.0529487,
#  1.3298064,
#  1.6986905,
#  1.4669126,
#  1.7824862,
#  2.0047226,
#  1.6879624,
#  2.2192497,
#  2.132401,
#  1.6619506,
#  1.3595934,
#  1.4540182,
#  2.456699,
#  1.54389,
#  1.9120667,
#  1.6550205,
#  1.3657029,
#  2.2842503,
#  1.6637614,
#  1.6462853,
#  2.9843025,
#  2.6817749,
#  1.456302,
#  1.7825582,
#  1.8744005,
#  1.5017081,
#  1.3193071,
#  1.8474871,
#  1.9820048,
#  1.673901,
#  1.3828665,
#  1.6489295,
#  1.4304491,
#  1.792745,
#  1.7139771,
#  1.4691257,
#  1.5597967,
#  1.894816,
#  1.6239436,
#  1.4322598,
#  2.1351035,
#  1.2838143,
#  1.613655,
#  1.8020349,
#  1.6216322,
#  1.8792646,
#  1.8245062,
#  2.1025717,
#  2.4829633,
#  1.7367218,
#  1.703874,
#  1.7306992,
#  1.5731622,
#  1.9680142,
#  1.7308077,
#  1.8059211,
#  1.668698,
#  1.4697381,
#  2.1778605,
#  2.6858804,
#  2.196402,
#  1.4907883,
#  1.6768947,
#  1.6070164,
#  1.3584739,
#  1.8480525,
#  1.3532587,
#  1.4325211,
#  1.4669944,
#  2.7280793,
#  1.7932167,
#  1.737785,
#  1.1152121,
#  1.03987,
#  1.8412766,
#  1.7874475,
#  1.8308183,
#  1.8049369,
#  1.6918012,
#  2.009357,
#  1.9224116,
#  1.9150509,
#  1.616193,
#  1.614115,
#  1.507196,
#  1.4791195,
#  1.3256584,
#  1.7674165,
#  1.2487413,
#  1.9719743,
#  1.3630208,
#  1.8405615,
#  1.530372,
#  2.439906,
#  2.067903,
#  1.3431591,
#  2.1722422,
#  1.6004058,
#  1.579454,
#  1.842873,
#  1.9640033,
#  1.7802665,
#  1.714322,
#  2.01574,
#  1.7889162,
#  1.7517484,
#  1.5153346,
#  2.021028,
#  1.3854454,
#  1.4199902,
#  1.3861537,
#  1.9983001,
#  1.791619,
#  1.6323899,
#  1.9710451,
#  1.6086954,
#  1.2989469,
#  1.258052,
#  1.5975957,
#  1.7914369,
#  1.5957502,
#  2.017729,
#  1.3044052,
#  1.2772002,
#  1.321213,
#  1.8025004,
#  2.0262957,
#  1.7207674,
#  1.5863966,
#  1.5037014,
#  1.9073968,
#  1.6215644,
#  1.5379176,
#  1.8644183,
#  1.3776494,
#  2.169999,
#  1.590602,
#  1.5686476,
#  1.8537875,
#  1.5690907,
#  2.2559144,
#  1.9737331,
#  1.6441848,
#  2.7689767,
#  1.5243124,
#  2.6837046,
#  2.0585926,
#  1.760403,
#  1.9093554,
#  3.239914,
#  1.9676708,
#  1.7674907,
#  1.9043291,
#  1.5967916,
#  1.6981417,
#  2.0613208,
#  2.36853,
#  2.0777333,
#  2.0069036,
#  1.6564406,
#  1.5701615,
#  1.922484,
#  1.882683,
#  1.363385,
#  1.435469,
#  1.4013739,
#  1.8876686,
#  1.7881538,
#  1.5656074,
#  1.7150489,
#  1.2932284,
#  1.8181976,
#  1.4246567,
#  1.9015055,
#  ...]

# %%
next(iter(load("project/theirprotbert.test.pkl").values())).shape
# Out:
# (1024,)

# %%
next(iter(load("project/protbert.test.pkl").values())).shape
# Out:
# (1024,)

# %%
# Prepare the set of annotations for our train set

# %%
def filter_annotations(annotations_file, id_set, output_file):
    with open(annotations_file, 'r') as in_file:
        with open(output_file, 'w') as out_file:
            for line in in_file.readlines():
                line_id = line.split()[0]
                if line_id in id_set:
                    print(line, file=out_file, end='') #line already has newline

# %%
filter_annotations("goa_annotations_exp_2017.txt", train_ids, "project_annotations.txt")

# %%
def produce_configs():
    #os.mkdir("configs")
    for model in ("theirprotbert",):#"prott5", "seqvec", "esm2", "protbert", "proteinbert":
        with open(os.path.join("configs", f"{model}_config.txt"), 'w') as config_file:
            print("go: data/GO/go_cafa3.obo", file=config_file)
            print(f"lookup_set: project/{model}.train.pkl", file=config_file)
            print(f"annotations: project_annotations.txt", file= config_file)
            print(f"targets: project/{model}.test.pkl", file=config_file)
            print(f"onto: all", file=config_file)
            print(f"thresh: 1", file=config_file)
            print(f"modus: num", file=config_file)
            print(f"output: results/{model}", file=config_file)

# %%
produce_configs()

# %%
from yaml import load, dump

# %%
import os
import yaml

# %%
def produce_assess():
    #os.mkdir("assess_configs")
    for model in ("theirprotbert",):#"prott5", "seqvec", "esm2", "protbert", "proteinbert":
        for onto in "BPO", "MFO", "CCO": 
            d = {
                "file" : f"predictions/{model}-Tch_1_all_go_{onto}.txt",
                "obo": "./precrec/go_cafa3.obo",
                "benchmark": "./precrec/benchmark/CAFA3_benchmarks/",
                "results": "./results"
            }
            conf = yaml.dump({"assess": d, "plot": {}})
            with open(f"assess_configs/{model}_{onto}.yaml", 'w') as opened:
                print(conf, file=opened, end='')

# %%
produce_assess()

# %%
#this cell has been created with chatgpt
import os
import pandas as pd

def parse_result_file(file_path):
    result_data = {}
    ontology_matched = False
    model = file_path.split("_")[1]
    ontology = file_path.split("_")[-1].split(".")[0].upper()

    with open(file_path, 'r') as file:
        lines = file.readlines()

    mode = None
    benchmark_type = None

    for line in lines:
        line = line.strip()
        if line.startswith("ontology:"):
            current_ontology = line.split(":")[1].strip().upper()
            if current_ontology == ontology:
                ontology_matched = True
            else:
                ontology_matched = False
        elif ontology_matched:
            if line.startswith("mode:"):
                mode = line.split(":")[1].strip()
            elif line.startswith("benchmark type:"):
                benchmark_type = line.split(":")[1].strip()
            elif line.startswith("fmax:") and mode == "full":
                fmax = float(line.split(":")[1].strip())
                key = (benchmark_type, ontology, model)
                result_data.setdefault(key, {})['fmax'] = fmax
            elif line.startswith("threshold giving fmax:") and mode == "full":
                threshold = float(line.split(":")[1].strip())
                key = (benchmark_type, ontology, model)
                result_data.setdefault(key, {})['threshold'] = threshold

    return result_data


# Iterate over all files in the output directory
output_dir = "assessment_output-euclidean"
fmax_results = []
threshold_results = []

for file_name in os.listdir(output_dir):
    file_path = os.path.join(output_dir, file_name)

    # Parse the result file
    result_data = parse_result_file(file_path)

    # Store the extracted data in a list of dictionaries
    if result_data:
        fmaxes = {key: data['fmax'] for key, data in result_data.items() if 'threshold' in data}
        fmax_results.extend(fmaxes.items())

        # Extract the threshold data
        thresholds = {key: data['threshold'] for key, data in result_data.items() if 'threshold' in data}
        threshold_results.extend(thresholds.items())

# Create a DataFrame for fmax values
fmax_df = pd.DataFrame(fmax_results, columns=['benchmark_type_ontology_model', 'results'])
fmax_df[['benchmark_type', 'ontology', 'model']] = pd.DataFrame(fmax_df['benchmark_type_ontology_model'].tolist(), index=fmax_df.index)
fmax_df = fmax_df.drop('benchmark_type_ontology_model', axis=1)

# Pivot the fmax DataFrame
fmax_pivot = fmax_df.pivot(index='model', columns=['benchmark_type', 'ontology'], values='results')

# Create a DataFrame for thresholds
threshold_df = pd.DataFrame(threshold_results, columns=['benchmark_type_ontology_model', 'threshold'])
threshold_df[['benchmark_type', 'ontology', 'model']] = pd.DataFrame(threshold_df['benchmark_type_ontology_model'].tolist(), index=threshold_df.index)
threshold_df = threshold_df.drop('benchmark_type_ontology_model', axis=1)

# Pivot the threshold DataFrame
threshold_pivot = threshold_df.pivot(index='model', columns=['benchmark_type', 'ontology'], values='threshold')

# Print the fmax DataFrame
print("Fmax DataFrame:")
print(fmax_pivot)

# Print the threshold DataFrame
print("\nThreshold DataFrame:")
print(threshold_pivot)

euclidean_df = fmax_pivot
# Out:
# Fmax DataFrame:
# benchmark_type                        NK        LK        NK        LK  \
# ontology                             BPO       BPO       CCO       CCO
# model
# output-euclidean/esm2           0.320937  0.340213  0.575237  0.570138
# output-euclidean/protbert       0.260052  0.315406  0.538194  0.537135
# output-euclidean/proteinbert    0.311029  0.362275  0.571419  0.543442
# output-euclidean/prott5         0.324303  0.331968  0.588554  0.566115
# output-euclidean/seqvec         0.305571  0.292032  0.561114  0.540299
# output-euclidean/theirprotbert  0.297858  0.330947  0.567013  0.538607
#
# benchmark_type                        NK        LK
# ontology                             MFO       MFO
# model
# output-euclidean/esm2           0.504384  0.441647
# output-euclidean/protbert       0.398696  0.348051
# output-euclidean/proteinbert    0.511744  0.451957
# output-euclidean/prott5         0.531228  0.462393
# output-euclidean/seqvec         0.496337  0.421948
# output-euclidean/theirprotbert  0.472835  0.431698
#
# Threshold DataFrame:
# benchmark_type                    NK    LK    NK    LK    NK    LK
# ontology                         BPO   BPO   CCO   CCO   MFO   MFO
# model
# output-euclidean/esm2           0.19  0.20  0.13  0.20  0.21  0.14
# output-euclidean/protbert       0.28  0.16  0.21  0.21  0.11  0.12
# output-euclidean/proteinbert    0.09  0.07  0.07  0.06  0.04  0.05
# output-euclidean/prott5         0.30  0.30  0.19  0.30  0.19  0.18
# output-euclidean/seqvec         0.32  0.38  0.25  0.29  0.28  0.22
# output-euclidean/theirprotbert  0.35  0.32  0.28  0.34  0.25  0.13

# %%
#this cell has been created with chatgpt
import os
import pandas as pd

def parse_result_file(file_path):
    result_data = {}
    ontology_matched = False
    model = file_path.split("_")[1]
    ontology = file_path.split("_")[-1].split(".")[0].upper()

    with open(file_path, 'r') as file:
        lines = file.readlines()

    mode = None
    benchmark_type = None

    for line in lines:
        line = line.strip()
        if line.startswith("ontology:"):
            current_ontology = line.split(":")[1].strip().upper()
            if current_ontology == ontology:
                ontology_matched = True
            else:
                ontology_matched = False
        elif ontology_matched:
            if line.startswith("mode:"):
                mode = line.split(":")[1].strip()
            elif line.startswith("benchmark type:"):
                benchmark_type = line.split(":")[1].strip()
            elif line.startswith("fmax:") and mode == "full":
                fmax = float(line.split(":")[1].strip())
                key = (benchmark_type, ontology, model)
                result_data.setdefault(key, {})['fmax'] = fmax
            elif line.startswith("threshold giving fmax:") and mode == "full":
                threshold = float(line.split(":")[1].strip())
                key = (benchmark_type, ontology, model)
                result_data.setdefault(key, {})['threshold'] = threshold

    return result_data


# Iterate over all files in the output directory
output_dir = "assessment_output-cosine"
fmax_results = []
threshold_results = []

for file_name in os.listdir(output_dir):
    file_path = os.path.join(output_dir, file_name)

    # Parse the result file
    result_data = parse_result_file(file_path)

    # Store the extracted data in a list of dictionaries
    if result_data:
        fmaxes = {key: data['fmax'] for key, data in result_data.items() if 'threshold' in data}
        fmax_results.extend(fmaxes.items())

        # Extract the threshold data
        thresholds = {key: data['threshold'] for key, data in result_data.items() if 'threshold' in data}
        threshold_results.extend(thresholds.items())

fmax_results
# Create a DataFrame for fmax values
fmax_df = pd.DataFrame(fmax_results, columns=['benchmark_type_ontology_model', 'results'])
fmax_df[['benchmark_type', 'ontology', 'model']] = pd.DataFrame(fmax_df['benchmark_type_ontology_model'].tolist(), index=fmax_df.index)
fmax_df = fmax_df.drop('benchmark_type_ontology_model', axis=1)

# Pivot the fmax DataFrame
fmax_pivot = fmax_df.pivot(index='model', columns=['benchmark_type', 'ontology'], values='results')

# Create a DataFrame for thresholds
threshold_df = pd.DataFrame(threshold_results, columns=['benchmark_type_ontology_model', 'threshold'])
threshold_df[['benchmark_type', 'ontology', 'model']] = pd.DataFrame(threshold_df['benchmark_type_ontology_model'].tolist(), index=threshold_df.index)
threshold_df = threshold_df.drop('benchmark_type_ontology_model', axis=1)

# Pivot the threshold DataFrame
threshold_pivot = threshold_df.pivot(index='model', columns=['benchmark_type', 'ontology'], values='threshold')

# Print the fmax DataFrame
print("Fmax DataFrame:")
print(fmax_pivot)

# Print the threshold DataFrame
print("\nThreshold DataFrame:")
print(threshold_pivot)
cosine_df = fmax_pivot
# Out:
# Fmax DataFrame:
# benchmark_type                     NK        LK        NK        LK        NK  \
# ontology                          BPO       BPO       CCO       CCO       MFO
# model
# output-cosine/esm2           0.319165  0.343183  0.583947  0.563275  0.510816
# output-cosine/protbert       0.264061  0.314596  0.537240  0.534392  0.397974
# output-cosine/proteinbert    0.308999  0.367301  0.572998  0.536269  0.522469
# output-cosine/prott5         0.321928  0.332805  0.586196  0.562986  0.541229
# output-cosine/seqvec         0.311946  0.298345  0.558143  0.532568  0.521211
# output-cosine/theirprotbert  0.297631  0.329151  0.561851  0.545227  0.470573
#
# benchmark_type                     LK
# ontology                          MFO
# model
# output-cosine/esm2           0.454607
# output-cosine/protbert       0.350704
# output-cosine/proteinbert    0.444916
# output-cosine/prott5         0.457018
# output-cosine/seqvec         0.428593
# output-cosine/theirprotbert  0.418304
#
# Threshold DataFrame:
# benchmark_type                 NK    LK    NK    LK    NK    LK
# ontology                      BPO   BPO   CCO   CCO   MFO   MFO
# model
# output-cosine/esm2           0.50  0.33  0.88  0.50  0.50  0.25
# output-cosine/protbert       0.98  0.50  0.91  0.33  0.50  0.25
# output-cosine/proteinbert    0.47  0.75  0.64  0.65  0.26  0.25
# output-cosine/prott5         0.66  0.61  0.49  0.70  0.43  0.25
# output-cosine/seqvec         0.83  0.71  0.68  0.77  0.70  0.73
# output-cosine/theirprotbert  0.88  0.45  0.80  0.70  0.32  0.25

# %%
euclidean_df
# Out:
# benchmark_type                        NK        LK        NK        LK  \
# ontology                             BPO       BPO       CCO       CCO
# model
# output-euclidean/esm2           0.320937  0.340213  0.575237  0.570138
# output-euclidean/protbert       0.260052  0.315406  0.538194  0.537135
# output-euclidean/proteinbert    0.311029  0.362275  0.571419  0.543442
# output-euclidean/prott5         0.324303  0.331968  0.588554  0.566115
# output-euclidean/seqvec         0.305571  0.292032  0.561114  0.540299
# output-euclidean/theirprotbert  0.297858  0.330947  0.567013  0.538607
#
# benchmark_type                        NK        LK
# ontology                             MFO       MFO
# model
# output-euclidean/esm2           0.504384  0.441647
# output-euclidean/protbert       0.398696  0.348051
# output-euclidean/proteinbert    0.511744  0.451957
# output-euclidean/prott5         0.531228  0.462393
# output-euclidean/seqvec         0.496337  0.421948
# output-euclidean/theirprotbert  0.472835  0.431698

# %%
cosine_df
# Out:
# benchmark_type                     NK        LK        NK        LK        NK  \
# ontology                          BPO       BPO       CCO       CCO       MFO
# model
# output-cosine/esm2           0.319165  0.343183  0.583947  0.563275  0.510816
# output-cosine/protbert       0.264061  0.314596  0.537240  0.534392  0.397974
# output-cosine/proteinbert    0.308999  0.367301  0.572998  0.536269  0.522469
# output-cosine/prott5         0.321928  0.332805  0.586196  0.562986  0.541229
# output-cosine/seqvec         0.311946  0.298345  0.558143  0.532568  0.521211
# output-cosine/theirprotbert  0.297631  0.329151  0.561851  0.545227  0.470573
#
# benchmark_type                     LK
# ontology                          MFO
# model
# output-cosine/esm2           0.454607
# output-cosine/protbert       0.350704
# output-cosine/proteinbert    0.444916
# output-cosine/prott5         0.457018
# output-cosine/seqvec         0.428593
# output-cosine/theirprotbert  0.418304

# %%
combined = pd.concat([euclidean_df, cosine_df])

# %%
combined
# Out:
# benchmark_type                        NK        LK        NK        LK  \
# ontology                             BPO       BPO       CCO       CCO
# model
# output-euclidean/esm2           0.320937  0.340213  0.575237  0.570138
# output-euclidean/protbert       0.260052  0.315406  0.538194  0.537135
# output-euclidean/proteinbert    0.311029  0.362275  0.571419  0.543442
# output-euclidean/prott5         0.324303  0.331968  0.588554  0.566115
# output-euclidean/seqvec         0.305571  0.292032  0.561114  0.540299
# output-euclidean/theirprotbert  0.297858  0.330947  0.567013  0.538607
# output-cosine/esm2              0.319165  0.343183  0.583947  0.563275
# output-cosine/protbert          0.264061  0.314596  0.537240  0.534392
# output-cosine/proteinbert       0.308999  0.367301  0.572998  0.536269
# output-cosine/prott5            0.321928  0.332805  0.586196  0.562986
# output-cosine/seqvec            0.311946  0.298345  0.558143  0.532568
# output-cosine/theirprotbert     0.297631  0.329151  0.561851  0.545227
#
# benchmark_type                        NK        LK
# ontology                             MFO       MFO
# model
# output-euclidean/esm2           0.504384  0.441647
# output-euclidean/protbert       0.398696  0.348051
# output-euclidean/proteinbert    0.511744  0.451957
# output-euclidean/prott5         0.531228  0.462393
# output-euclidean/seqvec         0.496337  0.421948
# output-euclidean/theirprotbert  0.472835  0.431698
# output-cosine/esm2              0.510816  0.454607
# output-cosine/protbert          0.397974  0.350704
# output-cosine/proteinbert       0.522469  0.444916
# output-cosine/prott5            0.541229  0.457018
# output-cosine/seqvec            0.521211  0.428593
# output-cosine/theirprotbert     0.470573  0.418304

# %%
combined.columns
# Out:
# MultiIndex([('NK', 'BPO'),
#             ('LK', 'BPO'),
#             ('NK', 'CCO'),
#             ('LK', 'CCO'),
#             ('NK', 'MFO'),
#             ('LK', 'MFO')],
#            names=['benchmark_type', 'ontology'])

# %%
name_mapping = {name: name[len("output-"):] for name in combined.index}
for d in "euclidean", "cosine":
    name_mapping[f"output-{d}/protbert"] = f"{d}/protbert-ur100"
    name_mapping[f"output-{d}/theirprotbert"] = f"{d}/protbert-bfd"
combined = combined.rename(index=name_mapping)

# %%
combined
# Out:
# benchmark_type                  NK        LK        NK        LK        NK  \
# ontology                       BPO       BPO       CCO       CCO       MFO
# model
# euclidean/esm2            0.320937  0.340213  0.575237  0.570138  0.504384
# euclidean/protbert-ur100  0.260052  0.315406  0.538194  0.537135  0.398696
# euclidean/proteinbert     0.311029  0.362275  0.571419  0.543442  0.511744
# euclidean/prott5          0.324303  0.331968  0.588554  0.566115  0.531228
# euclidean/seqvec          0.305571  0.292032  0.561114  0.540299  0.496337
# euclidean/protbert-bfd    0.297858  0.330947  0.567013  0.538607  0.472835
# cosine/esm2               0.319165  0.343183  0.583947  0.563275  0.510816
# cosine/protbert-ur100     0.264061  0.314596  0.537240  0.534392  0.397974
# cosine/proteinbert        0.308999  0.367301  0.572998  0.536269  0.522469
# cosine/prott5             0.321928  0.332805  0.586196  0.562986  0.541229
# cosine/seqvec             0.311946  0.298345  0.558143  0.532568  0.521211
# cosine/protbert-bfd       0.297631  0.329151  0.561851  0.545227  0.470573
#
# benchmark_type                  LK
# ontology                       MFO
# model
# euclidean/esm2            0.441647
# euclidean/protbert-ur100  0.348051
# euclidean/proteinbert     0.451957
# euclidean/prott5          0.462393
# euclidean/seqvec          0.421948
# euclidean/protbert-bfd    0.431698
# cosine/esm2               0.454607
# cosine/protbert-ur100     0.350704
# cosine/proteinbert        0.444916
# cosine/prott5             0.457018
# cosine/seqvec             0.428593
# cosine/protbert-bfd       0.418304

# %%
combined_lk =  combined.loc[:, combined.columns.get_level_values(0) == 'LK']
combined_lk.columns = combined_lk.columns.droplevel(0)

# %%
combined_lk
# Out:
# ontology                       BPO       CCO       MFO
# model
# euclidean/esm2            0.340213  0.570138  0.441647
# euclidean/protbert-ur100  0.315406  0.537135  0.348051
# euclidean/proteinbert     0.362275  0.543442  0.451957
# euclidean/prott5          0.331968  0.566115  0.462393
# euclidean/seqvec          0.292032  0.540299  0.421948
# euclidean/protbert-bfd    0.330947  0.538607  0.431698
# cosine/esm2               0.343183  0.563275  0.454607
# cosine/protbert-ur100     0.314596  0.534392  0.350704
# cosine/proteinbert        0.367301  0.536269  0.444916
# cosine/prott5             0.332805  0.562986  0.457018
# cosine/seqvec             0.298345  0.532568  0.428593
# cosine/protbert-bfd       0.329151  0.545227  0.418304

# %%
combined_nk =  combined.loc[:, combined.columns.get_level_values(0) == 'NK']
combined_nk.columns = combined_nk.columns.droplevel(0)

# %%
combined_nk
# Out:
# ontology                       BPO       CCO       MFO
# model
# euclidean/esm2            0.320937  0.575237  0.504384
# euclidean/protbert-ur100  0.260052  0.538194  0.398696
# euclidean/proteinbert     0.311029  0.571419  0.511744
# euclidean/prott5          0.324303  0.588554  0.531228
# euclidean/seqvec          0.305571  0.561114  0.496337
# euclidean/protbert-bfd    0.297858  0.567013  0.472835
# cosine/esm2               0.319165  0.583947  0.510816
# cosine/protbert-ur100     0.264061  0.537240  0.397974
# cosine/proteinbert        0.308999  0.572998  0.522469
# cosine/prott5             0.321928  0.586196  0.541229
# cosine/seqvec             0.311946  0.558143  0.521211
# cosine/protbert-bfd       0.297631  0.561851  0.470573

# %%
print(combined_lk.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# ontology &       BPO &       CCO &       MFO \\
# model                    &           &           &           \\
# \midrule
# euclidean/esm2           &  0.340213 &  0.570138 &  0.441647 \\
# euclidean/protbert-ur100 &  0.315406 &  0.537135 &  0.348051 \\
# euclidean/proteinbert    &  0.362275 &  0.543442 &  0.451957 \\
# euclidean/prott5         &  0.331968 &  0.566115 &  0.462393 \\
# euclidean/seqvec         &  0.292032 &  0.540299 &  0.421948 \\
# euclidean/protbert-bfd   &  0.330947 &  0.538607 &  0.431698 \\
# cosine/esm2              &  0.343183 &  0.563275 &  0.454607 \\
# cosine/protbert-ur100    &  0.314596 &  0.534392 &  0.350704 \\
# cosine/proteinbert       &  0.367301 &  0.536269 &  0.444916 \\
# cosine/prott5            &  0.332805 &  0.562986 &  0.457018 \\
# cosine/seqvec            &  0.298345 &  0.532568 &  0.428593 \\
# cosine/protbert-bfd      &  0.329151 &  0.545227 &  0.418304 \\
# \bottomrule
# \end{tabular}
# <ipython-input-55-748e7aecc6b4>:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(combined_lk.to_latex())

# %%
print(combined_nk.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# ontology &       BPO &       CCO &       MFO \\
# model                    &           &           &           \\
# \midrule
# euclidean/esm2           &  0.320937 &  0.575237 &  0.504384 \\
# euclidean/protbert-ur100 &  0.260052 &  0.538194 &  0.398696 \\
# euclidean/proteinbert    &  0.311029 &  0.571419 &  0.511744 \\
# euclidean/prott5         &  0.324303 &  0.588554 &  0.531228 \\
# euclidean/seqvec         &  0.305571 &  0.561114 &  0.496337 \\
# euclidean/protbert-bfd   &  0.297858 &  0.567013 &  0.472835 \\
# cosine/esm2              &  0.319165 &  0.583947 &  0.510816 \\
# cosine/protbert-ur100    &  0.264061 &  0.537240 &  0.397974 \\
# cosine/proteinbert       &  0.308999 &  0.572998 &  0.522469 \\
# cosine/prott5            &  0.321928 &  0.586196 &  0.541229 \\
# cosine/seqvec            &  0.311946 &  0.558143 &  0.521211 \\
# cosine/protbert-bfd      &  0.297631 &  0.561851 &  0.470573 \\
# \bottomrule
# \end{tabular}
# <ipython-input-56-63c3068ff106>:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(combined_nk.to_latex())

# %%
repr(combined_lk.to_dict())
# Out:
# "{'BPO': {'euclidean/esm2': 0.3402128490521757, 'euclidean/protbert-ur100': 0.31540560610418666, 'euclidean/proteinbert': 0.36227507914950674, 'euclidean/prott5': 0.33196811496519074, 'euclidean/seqvec': 0.2920315408988826, 'euclidean/protbert-bfd': 0.33094730264537603, 'cosine/esm2': 0.3431828174196418, 'cosine/protbert-ur100': 0.3145956336279498, 'cosine/proteinbert': 0.36730118795227124, 'cosine/prott5': 0.3328045729998566, 'cosine/seqvec': 0.2983453828330413, 'cosine/protbert-bfd': 0.3291509340108948}, 'CCO': {'euclidean/esm2': 0.5701380876505326, 'euclidean/protbert-ur100': 0.5371354196185177, 'euclidean/proteinbert': 0.5434421350680555, 'euclidean/prott5': 0.5661153459122396, 'euclidean/seqvec': 0.540298933471445, 'euclidean/protbert-bfd': 0.5386074093409604, 'cosine/esm2': 0.56327549723111, 'cosine/protbert-ur100': 0.5343917945928709, 'cosine/proteinbert': 0.5362689622488322, 'cosine/prott5': 0.5629856555171122, 'cosine/seqvec': 0.5325684029490236, 'cosine/protbert-bfd': 0.5452266244063264}, 'MFO': {'euclidean/esm2': 0.4416468222546291, 'euclidean/protbert-ur100': 0.3480513545179189, 'euclidean/proteinbert': 0.45195701580943526, 'euclidean/prott5': 0.4623928456600475, 'euclidean/seqvec': 0.4219479596457337, 'euclidean/protbert-bfd': 0.43169768985288465, 'cosine/esm2': 0.4546069655838999, 'cosine/protbert-ur100': 0.3507041730403241, 'cosine/proteinbert': 0.4449159105223092, 'cosine/prott5': 0.45701779634416206, 'cosine/seqvec': 0.42859324370839386, 'cosine/protbert-bfd': 0.41830417718269286}}"

# %%
repr(combined_nk.to_dict())
# Out:
# "{'BPO': {'euclidean/esm2': 0.320937030946012, 'euclidean/protbert-ur100': 0.26005151322540027, 'euclidean/proteinbert': 0.3110287219554749, 'euclidean/prott5': 0.3243030066201612, 'euclidean/seqvec': 0.3055714646633119, 'euclidean/protbert-bfd': 0.29785826432243917, 'cosine/esm2': 0.3191653498509426, 'cosine/protbert-ur100': 0.26406124274401904, 'cosine/proteinbert': 0.3089987882973226, 'cosine/prott5': 0.3219275394528631, 'cosine/seqvec': 0.31194621384746163, 'cosine/protbert-bfd': 0.2976306478121041}, 'CCO': {'euclidean/esm2': 0.5752366600780419, 'euclidean/protbert-ur100': 0.5381941944811517, 'euclidean/proteinbert': 0.5714186618318124, 'euclidean/prott5': 0.5885544854825134, 'euclidean/seqvec': 0.5611140121392842, 'euclidean/protbert-bfd': 0.5670125831368363, 'cosine/esm2': 0.5839474233111744, 'cosine/protbert-ur100': 0.5372396511878191, 'cosine/proteinbert': 0.5729976347154231, 'cosine/prott5': 0.5861962463960505, 'cosine/seqvec': 0.5581434988264784, 'cosine/protbert-bfd': 0.5618506503110158}, 'MFO': {'euclidean/esm2': 0.5043840210453248, 'euclidean/protbert-ur100': 0.39869641428870745, 'euclidean/proteinbert': 0.5117442173920967, 'euclidean/prott5': 0.5312275584521786, 'euclidean/seqvec': 0.4963372830515264, 'euclidean/protbert-bfd': 0.4728348014083753, 'cosine/esm2': 0.5108162370889814, 'cosine/protbert-ur100': 0.3979736574652955, 'cosine/proteinbert': 0.52246873663165, 'cosine/prott5': 0.5412286110334799, 'cosine/seqvec': 0.5212109304804815, 'cosine/protbert-bfd': 0.47057285144778477}}"
